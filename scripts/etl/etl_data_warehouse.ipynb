# %%
import requests
import pandas as pd
import os
from pathlib import Path
from etl_functions import _safe_save, extract, convert_columns_to_json, transform_products, transform_carts, create_reviews_table, load

# %%
links = {
    "products": "https://dummyjson.com/products",
    "carts":   "https://dummyjson.com/carts",
    "users":    "https://dummyjson.com/users"
}

# %%
dataframes = {}

for name, link in links.items():
    df = extract(url=link, file_path="raw_data")
    dataframes[name] = df

# %%
products_df_raw = dataframes["products"]
products_df_raw = convert_columns_to_json(df=products_df_raw, columns = ["tags", "reviews", "images"])
products_df_raw.head()
# Out:
#    id                          title  \
# 0   1  Essence Mascara Lash Princess
# 1   2  Eyeshadow Palette with Mirror
# 2   3                Powder Canister
# 3   4                   Red Lipstick
# 4   5                Red Nail Polish
#
#                                          description category  price  \
# 0  The Essence Mascara Lash Princess is a popular...   beauty   9.99
# 1  The Eyeshadow Palette with Mirror offers a ver...   beauty  19.99
# 2  The Powder Canister is a finely milled setting...   beauty  14.99
# 3  The Red Lipstick is a classic and bold choice ...   beauty  12.99
# 4  The Red Nail Polish offers a rich and glossy r...   beauty   8.99
#
#    discountPercentage  rating  stock                       tags  \
# 0               10.48    2.56     99      ["beauty", "mascara"]
# 1               18.19    2.86     34    ["beauty", "eyeshadow"]
# 2                9.84    4.64     89  ["beauty", "face powder"]
# 3               12.16    4.36     91     ["beauty", "lipstick"]
# 4               11.44    4.32     79  ["beauty", "nail polish"]
#
#             brand  ... minimumOrderQuantity  \
# 0         Essence  ...                   48
# 1  Glamour Beauty  ...                   20
# 2    Velvet Touch  ...                   22
# 3  Chic Cosmetics  ...                   40
# 4    Nail Couture  ...                   22
#
#                                               images  \
# 0  ["https://cdn.dummyjson.com/product-images/bea...
# 1  ["https://cdn.dummyjson.com/product-images/bea...
# 2  ["https://cdn.dummyjson.com/product-images/bea...
# 3  ["https://cdn.dummyjson.com/product-images/bea...
# 4  ["https://cdn.dummyjson.com/product-images/bea...
#
#                                            thumbnail dimensions.width  \
# 0  https://cdn.dummyjson.com/product-images/beaut...            15.14
# 1  https://cdn.dummyjson.com/product-images/beaut...             9.26
# 2  https://cdn.dummyjson.com/product-images/beaut...            29.27
# 3  https://cdn.dummyjson.com/product-images/beaut...            18.11
# 4  https://cdn.dummyjson.com/product-images/beaut...            21.63
#
#   dimensions.height dimensions.depth            meta.createdAt  \
# 0             13.08            22.99  2025-04-30T09:41:02.053Z
# 1             22.47            27.67  2025-04-30T09:41:02.053Z
# 2             27.93            20.59  2025-04-30T09:41:02.053Z
# 3             28.38            22.17  2025-04-30T09:41:02.053Z
# 4             16.48            29.84  2025-04-30T09:41:02.053Z
#
#              meta.updatedAt   meta.barcode  \
# 0  2025-04-30T09:41:02.053Z  5784719087687
# 1  2025-04-30T09:41:02.053Z  9170275171413
# 2  2025-04-30T09:41:02.053Z  8418883906837
# 3  2025-04-30T09:41:02.053Z  9467746727219
# 4  2025-04-30T09:41:02.053Z  4063010628104
#
#                                     meta.qrCode
# 0  https://cdn.dummyjson.com/public/qr-code.png
# 1  https://cdn.dummyjson.com/public/qr-code.png
# 2  https://cdn.dummyjson.com/public/qr-code.png
# 3  https://cdn.dummyjson.com/public/qr-code.png
# 4  https://cdn.dummyjson.com/public/qr-code.png
#
# [5 rows x 27 columns]

# %%
column_mapping_products_raw = {
    "id": "product_id",
    "discountPercentage": "discount_percentage",
    "warrantyInformation": "warranty_information",
    "shippingInformation": "shipping_information",
    "availabilityStatus": "availability_status",
    "returnPolicy": "return_policy",
    "minimumOrderQuantity": "min_order_quantity",
    "dimensions.width": "dimension_width",
    "dimensions.height": "dimension_height",
    "dimensions.depth": "dimension_depth",
    "meta.createdAt": "meta_created_at",
    "meta.updatedAt": "meta_updated_at",
    "meta.barcode": "meta_barcode",
    "meta.qrCode": "meta_qr_code"
}

load(df=products_df_raw, table_name="products", schema="bronze", server = "DESKTOP-QBF1FTP\SQLEXPRESS", 
     database = "Dummydb", column_mapping = column_mapping_products_raw)
# Out:
# ✅ 194 rows loaded into bronze.products

# %%
carts_df_raw = dataframes["carts"]
carts_df_raw = convert_columns_to_json(df=carts_df_raw, columns = ["products"])
carts_df_raw.head()
# Out:
#    id                                           products      total  \
# 0   1  [{"id": 168, "title": "Charger SXT RWD", "pric...  103774.85
# 1   2  [{"id": 144, "title": "Cricket Helmet", "price...    4794.80
# 2   3  [{"id": 98, "title": "Rolex Submariner Watch",...   16775.87
# 3   4  [{"id": 187, "title": "Golden Shoes Woman", "p...     456.83
# 4   5  [{"id": 108, "title": "iPhone 12 Silicone Case...    7431.30
#
#    discountedTotal  userId  totalProducts  totalQuantity
# 0         89686.65      33              4             15
# 1          4288.95     142              5             20
# 2         14144.30     108              5             13
# 3           443.23      87              4             17
# 4          6676.44     134              6             20

# %%
column_mapping_carts_raw = {
    "id": "order_id",
    "discountedTotal": "discounted_total",
    "userId":"user_id",
    "totalProducts": "total_products",
    "totalQuantity": "total_quantity",
}

load(df=carts_df_raw, table_name="carts", schema="bronze", server = "DESKTOP-QBF1FTP\SQLEXPRESS", 
     database = "Dummydb", column_mapping=column_mapping_carts_raw)
# Out:
# ✅ 50 rows loaded into bronze.carts

# %%
users_df_raw = dataframes["users"]
users_df_raw.head()
# Out:
#    id firstName  lastName maidenName  age  gender  \
# 0   1     Emily   Johnson      Smith   28  female
# 1   2   Michael  Williams              35    male
# 2   3    Sophia     Brown              42  female
# 3   4     James     Davis              45    male
# 4   5      Emma    Miller    Johnson   30  female
#
#                               email             phone  username      password  \
# 0     emily.johnson@x.dummyjson.com  +81 965-431-3024    emilys    emilyspass
# 1  michael.williams@x.dummyjson.com  +49 258-627-6644  michaelw  michaelwpass
# 2      sophia.brown@x.dummyjson.com  +81 210-652-2785   sophiab   sophiabpass
# 3       james.davis@x.dummyjson.com  +49 614-958-9364    jamesd    jamesdpass
# 4       emma.miller@x.dummyjson.com  +91 759-776-1614     emmaj     emmajpass
#
#    ... company.address.city company.address.state company.address.stateCode  \
# 0  ...        San Francisco             Wisconsin                        WI
# 1  ...          Los Angeles         New Hampshire                        NH
# 2  ...               Dallas                Nevada                        NV
# 3  ...           Fort Worth          Pennsylvania                        PA
# 4  ...          San Antonio                 Idaho                        ID
#
#    company.address.postalCode  company.address.coordinates.lat  \
# 0                       37657                        71.814525
# 1                       73442                        79.098326
# 2                       88511                        20.086743
# 3                       27768                        54.911930
# 4                       21965                        44.346545
#
#   company.address.coordinates.lng company.address.country crypto.coin  \
# 0                     -161.150263           United States     Bitcoin
# 1                     -119.624845           United States     Bitcoin
# 2                      -34.577107           United States     Bitcoin
# 3                      -79.498328           United States     Bitcoin
# 4                      -26.944701           United States     Bitcoin
#
#                                 crypto.wallet    crypto.network
# 0  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 1  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 2  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 3  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 4  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
#
# [5 rows x 52 columns]

# %%
column_mapping_users_raw= {
    "id": "user_id",
    "firstName": "first_name",
    "lastName": "last_name",
    "maidenName": "maiden_name",
    "birthDate": "birthdate",
    "bloodGroup": "blood_group",
    "eyeColor": "eye_color",
    "macAddress": "mac_address",
    "userAgent": "user_agent",
    "hair.color": "hair_color",
    "hair.type": "hair_type",
    "address.address": "address_street",
    "address.city":"address_city",
    "address.state":"address_state",
    "address.stateCode": "address_state_code",
    "address.postalCode": "address_postal_code",
    "address.coordinates.lat": "address_coordinates_lat",
    "address.coordinates.lng": "address_coordinates_lng",
    "address.country":"address_country",
    "bank.cardExpire": "bank_card_expire",
    "bank.cardNumber": "bank_card_number",
    "bank.cardType": "bank_card_type",
    "bank.currency": "bank_currency",
    "bank.iban": "bank_iban",
    "company.department": "company_deparment",
    "company.name": "company_name",
    "company.title": "company_title",
    "company.address.address": "company_address_street",
    "company.address.city": "company_address_city",
    "company.address.state": "company_address_state",
    "company.address.stateCode": "company_address_state_code",
    "company.address.postalCode": "company_address_postal_code",
    "company.address.coordinates.lat": "company_address_coordinates_lat",
    "company.address.coordinates.lng": "company_address_coordinates_lng",
    "company.address.country": "company_address_country",
    "crypto.coin": "crypto_coin",
    "crypto.wallet": "crypto_wallet",
    "crypto.network": "crypto_network"
}


load(df=users_df_raw, table_name="users", schema="bronze", server = "DESKTOP-QBF1FTP\SQLEXPRESS", 
     database = "Dummydb", column_mapping=column_mapping_users_raw)
# Out:
# ✅ 208 rows loaded into bronze.users

# %%
products_df_transformed = transform_products(products_df_raw, out_dir="processed_data")
products_df_transformed.head()
# Out:
#    id                          title  \
# 0   1  Essence Mascara Lash Princess
# 1   2  Eyeshadow Palette with Mirror
# 2   3                Powder Canister
# 3   4                   Red Lipstick
# 4   5                Red Nail Polish
#
#                                          description category  subcategory  \
# 0  The Essence Mascara Lash Princess is a popular...   beauty      mascara
# 1  The Eyeshadow Palette with Mirror offers a ver...   beauty    eyeshadow
# 2  The Powder Canister is a finely milled setting...   beauty  face powder
# 3  The Red Lipstick is a classic and bold choice ...   beauty     lipstick
# 4  The Red Nail Polish offers a rich and glossy r...   beauty  nail polish
#
#    price  discountPercentage  rating  stock           brand  ... image_5  \
# 0   9.99               10.48    2.56     99         Essence  ...    None
# 1  19.99               18.19    2.86     34  Glamour Beauty  ...    None
# 2  14.99                9.84    4.64     89    Velvet Touch  ...    None
# 3  12.99               12.16    4.36     91  Chic Cosmetics  ...    None
# 4   8.99               11.44    4.32     79    Nail Couture  ...    None
#
#    image_6                                          thumbnail  \
# 0     None  https://cdn.dummyjson.com/product-images/beaut...
# 1     None  https://cdn.dummyjson.com/product-images/beaut...
# 2     None  https://cdn.dummyjson.com/product-images/beaut...
# 3     None  https://cdn.dummyjson.com/product-images/beaut...
# 4     None  https://cdn.dummyjson.com/product-images/beaut...
#
#   dimensions.width dimensions.height dimensions.depth  \
# 0            15.14             13.08            22.99
# 1             9.26             22.47            27.67
# 2            29.27             27.93            20.59
# 3            18.11             28.38            22.17
# 4            21.63             16.48            29.84
#
#              meta.createdAt            meta.updatedAt   meta.barcode  \
# 0  2025-04-30T09:41:02.053Z  2025-04-30T09:41:02.053Z  5784719087687
# 1  2025-04-30T09:41:02.053Z  2025-04-30T09:41:02.053Z  9170275171413
# 2  2025-04-30T09:41:02.053Z  2025-04-30T09:41:02.053Z  8418883906837
# 3  2025-04-30T09:41:02.053Z  2025-04-30T09:41:02.053Z  9467746727219
# 4  2025-04-30T09:41:02.053Z  2025-04-30T09:41:02.053Z  4063010628104
#
#                                     meta.qrCode
# 0  https://cdn.dummyjson.com/public/qr-code.png
# 1  https://cdn.dummyjson.com/public/qr-code.png
# 2  https://cdn.dummyjson.com/public/qr-code.png
# 3  https://cdn.dummyjson.com/public/qr-code.png
# 4  https://cdn.dummyjson.com/public/qr-code.png
#
# [5 rows x 31 columns]

# %%
column_mapping_products_transformed = {
    "id": "product_id",
    "discountPercentage": "discount_percentage",
    "warrantyInformation": "warranty_information",
    "shippingInformation": "shipping_information",
    "availabilityStatus": "availability_status",
    "returnPolicy": "return_policy",
    "minimumOrderQuantity": "min_order_quantity",
    "dimensions.width": "dimension_width",
    "dimensions.height": "dimension_height",
    "dimensions.depth": "dimension_depth",
    "meta.createdAt": "meta_created_at",
    "meta.updatedAt": "meta_updated_at",
    "meta.barcode": "meta_barcode",
    "meta.qrCode": "meta_qr_code"
}


load(df=products_df_transformed, table_name="products", schema="silver_prep", server = "DESKTOP-QBF1FTP\SQLEXPRESS", 
     database = "Dummydb", column_mapping = column_mapping_products_transformed)
# Out:
# ✅ 194 rows loaded into silver_prep.products

# %%
carts_df_transformed = transform_carts(carts_df_raw, out_dir="processed_data")
carts_df_transformed.head()
# Out:
#    id      total  discountedTotal  userId  totalProducts  totalQuantity  \
# 0   1  103774.85         89686.65      33              4             15
# 1   1  103774.85         89686.65      33              4             15
# 2   1  103774.85         89686.65      33              4             15
# 3   1  103774.85         89686.65      33              4             15
# 4   2    4794.80          4288.95     142              5             20
#
#    product_id                         product_title  product_price  \
# 0         168                       Charger SXT RWD       32999.99
# 1          78  Apple MacBook Pro 14 Inch Space Grey        1999.99
# 2         183                    Green Oval Earring          24.99
# 3         100                         Apple Airpods         129.99
# 4         144                        Cricket Helmet          44.99
#
#    product_quantity  product_total  product_discountPercentage  \
# 0                 3       98999.97                       13.39
# 1                 2        3999.98                       18.52
# 2                 5         124.95                        6.28
# 3                 5         649.95                       12.84
# 4                 4         179.96                       11.47
#
#    product_discountedTotal                                  product_thumbnail
# 0                 85743.87  https://cdn.dummyjson.com/products/images/vehi...
# 1                  3259.18  https://cdn.dummyjson.com/products/images/lapt...
# 2                   117.10  https://cdn.dummyjson.com/products/images/wome...
# 3                   566.50  https://cdn.dummyjson.com/products/images/mobi...
# 4                   159.32  https://cdn.dummyjson.com/products/images/spor...

# %%
column_mapping_carts_transformed= {
    "id": "order_id",
    "discountedTotal": "discounted_total",
    "userId":"user_id",
    "totalProducts": "total_products",
    "totalQuantity": "total_quantity",
    "product_discountPercentage": "product_discount_percentage",
    "product_discountedTotal":"product_discounted_total"
}

load(df=carts_df_transformed, table_name="carts", schema="silver_prep", server = "DESKTOP-QBF1FTP\SQLEXPRESS", 
     database = "Dummydb", column_mapping = column_mapping_carts_transformed)
# Out:
# ✅ 198 rows loaded into silver_prep.carts

# %%
users_df_transformed = users_df_raw
users_df_transformed.head()
# Out:
#    id firstName  lastName maidenName  age  gender  \
# 0   1     Emily   Johnson      Smith   28  female
# 1   2   Michael  Williams              35    male
# 2   3    Sophia     Brown              42  female
# 3   4     James     Davis              45    male
# 4   5      Emma    Miller    Johnson   30  female
#
#                               email             phone  username      password  \
# 0     emily.johnson@x.dummyjson.com  +81 965-431-3024    emilys    emilyspass
# 1  michael.williams@x.dummyjson.com  +49 258-627-6644  michaelw  michaelwpass
# 2      sophia.brown@x.dummyjson.com  +81 210-652-2785   sophiab   sophiabpass
# 3       james.davis@x.dummyjson.com  +49 614-958-9364    jamesd    jamesdpass
# 4       emma.miller@x.dummyjson.com  +91 759-776-1614     emmaj     emmajpass
#
#    ... company.address.city company.address.state company.address.stateCode  \
# 0  ...        San Francisco             Wisconsin                        WI
# 1  ...          Los Angeles         New Hampshire                        NH
# 2  ...               Dallas                Nevada                        NV
# 3  ...           Fort Worth          Pennsylvania                        PA
# 4  ...          San Antonio                 Idaho                        ID
#
#    company.address.postalCode  company.address.coordinates.lat  \
# 0                       37657                        71.814525
# 1                       73442                        79.098326
# 2                       88511                        20.086743
# 3                       27768                        54.911930
# 4                       21965                        44.346545
#
#   company.address.coordinates.lng company.address.country crypto.coin  \
# 0                     -161.150263           United States     Bitcoin
# 1                     -119.624845           United States     Bitcoin
# 2                      -34.577107           United States     Bitcoin
# 3                      -79.498328           United States     Bitcoin
# 4                      -26.944701           United States     Bitcoin
#
#                                 crypto.wallet    crypto.network
# 0  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 1  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 2  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 3  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 4  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
#
# [5 rows x 52 columns]

# %%
column_mapping_users_transformed= {
    "id": "user_id",
    "firstName": "first_name",
    "lastName": "last_name",
    "maidenName": "maiden_name",
    "birthDate": "birthdate",
    "bloodGroup": "blood_group",
    "eyeColor": "eye_color",
    "macAddress": "mac_address",
    "userAgent": "user_agent",
    "hair.color": "hair_color",
    "hair.type": "hair_type",
    "address.address": "address_street",
    "address.city":"address_city",
    "address.state":"address_state",
    "address.stateCode": "address_state_code",
    "address.postalCode": "address_postal_code",
    "address.coordinates.lat": "address_coordinates_lat",
    "address.coordinates.lng": "address_coordinates_lng",
    "address.country":"address_country",
    "bank.cardExpire": "bank_card_expire",
    "bank.cardNumber": "bank_card_number",
    "bank.cardType": "bank_card_type",
    "bank.currency": "bank_currency",
    "bank.iban": "bank_iban",
    "company.department": "company_deparment",
    "company.name": "company_name",
    "company.title": "company_title",
    "company.address.address": "company_address_street",
    "company.address.city": "company_address_city",
    "company.address.state": "company_address_state",
    "company.address.stateCode": "company_address_state_code",
    "company.address.postalCode": "company_address_postal_code",
    "company.address.coordinates.lat": "company_address_coordinates_lat",
    "company.address.coordinates.lng": "company_address_coordinates_lng",
    "company.address.country": "company_address_country",
    "crypto.coin": "crypto_coin",
    "crypto.wallet": "crypto_wallet",
    "crypto.network": "crypto_network"
}


load(df=users_df_transformed, table_name="users", schema="silver_prep", server = "DESKTOP-QBF1FTP\SQLEXPRESS", 
     database = "Dummydb", column_mapping=column_mapping_users_transformed)
# Out:
# ✅ 208 rows loaded into silver_prep.users

# %%
reviews_df = create_reviews_table(df=products_df_raw, out_dir="processed_data")
reviews_df
# Out:
#      review_id  product_id  rating                       comment  \
# 0            1           1       3          Would not recommend!
# 1            2           1       4               Very satisfied!
# 2            3           1       5             Highly impressed!
# 3            4           2       5                Great product!
# 4            5           2       4              Awesome product!
# ..         ...         ...     ...                           ...
# 577        578         193       4              Would buy again!
# 578        579         193       5                Great product!
# 579        580         194       4  Very happy with my purchase!
# 580        581         194       5           Highly recommended!
# 581        582         194       5                Fast shipping!
#
#                          date     reviewerName  \
# 0    2025-04-30T09:41:02.053Z  Eleanor Collins
# 1    2025-04-30T09:41:02.053Z     Lucas Gordon
# 2    2025-04-30T09:41:02.053Z  Eleanor Collins
# 3    2025-04-30T09:41:02.053Z   Savannah Gomez
# 4    2025-04-30T09:41:02.053Z  Christian Perez
# ..                        ...              ...
# 577  2025-04-30T09:41:02.054Z     Avery Barnes
# 578  2025-04-30T09:41:02.054Z   Evelyn Sanchez
# 579  2025-04-30T09:41:02.054Z     Harper Kelly
# 580  2025-04-30T09:41:02.054Z   Gabriel Bailey
# 581  2025-04-30T09:41:02.054Z    Natalie Price
#
#                        reviewerEmail
# 0    eleanor.collins@x.dummyjson.com
# 1       lucas.gordon@x.dummyjson.com
# 2    eleanor.collins@x.dummyjson.com
# 3     savannah.gomez@x.dummyjson.com
# 4    christian.perez@x.dummyjson.com
# ..                               ...
# 577     avery.barnes@x.dummyjson.com
# 578   evelyn.sanchez@x.dummyjson.com
# 579     harper.kelly@x.dummyjson.com
# 580   gabriel.bailey@x.dummyjson.com
# 581    natalie.price@x.dummyjson.com
#
# [582 rows x 7 columns]

# %%
column_mapping_reviews = {"reviewerName": "reviewer_name",
                          "reviewerEmail":"reviewer_email"}

load(df=reviews_df, table_name='reviews', schema="silver_prep", server="DESKTOP-QBF1FTP\SQLEXPRESS", 
     database="Dummydb", column_mapping=column_mapping_reviews)
# Out:
# ✅ 582 rows loaded into silver_prep.reviews
